# %% [markdown]
# # Week 5 — Visualization
#
# > **DEMO / SAMPLE DATA NOTICE:** This notebook uses a synthetic demonstration dataset created for the Week 5 reporting structure. It must not be presented as actual internship findings or real Week 1–4 results.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/processed/cleaned_dataset.csv")

# %%
# Distribution plots
fig, axes = plt.subplots(2,2, figsize=(10,7))
for ax, col in zip(axes.ravel(), ["sales","profit","quantity","discount"]):
    ax.hist(df[col], bins=20)
    ax.set_title(col.title())
plt.tight_layout()
plt.show()

# %%
# Category sales
df.groupby("category")["sales"].sum().sort_values(ascending=False).plot(kind="bar", figsize=(8,5))
plt.title("Total Sales by Category")
plt.ylabel("Sales")
plt.tight_layout()
plt.show()

# %%
# Correlation heatmap
corr = df.select_dtypes("number").corr()
plt.figure(figsize=(9,7))
plt.imshow(corr, interpolation="nearest")
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=45, ha="right")
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()
